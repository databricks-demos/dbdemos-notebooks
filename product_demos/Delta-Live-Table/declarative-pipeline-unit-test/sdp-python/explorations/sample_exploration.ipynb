# %% [markdown]
# ## Review Ingested Users dataset
#
# The ./dataset/users.json dataset contains:
#
# * 4 "standard users"
# * 1 user with Null ID
# * 1 user with an ID as a string

# %%
# %fs head /Volumes/main__build/dbdemos_sdp_unit_test/raw_data/test/users_json/users.json
